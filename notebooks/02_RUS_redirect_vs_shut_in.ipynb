# %%
import pandas as pd

df_ru = pd.read_csv('../data/russia_energy_sample.csv')
df_eu = pd.read_csv('../data/eu_energy_sample.csv')

# %%
df_ru.columns
# Out:
# Index(['Month', 'Production_TBPD', 'Production_K_Tonnes'], dtype='object')

# %%
"1. How much has russian oil production decreased since the begining of the was?"

yearly_averages = df_ru.groupby(df_ru['Month'].dt.year)[['Production_TBPD', 'Production_K_Tonnes']].mean()

print("--- Russian Production In Thousand Barrels Per Day And Thousands Of Tonnes (2022 - 2025) ---")
print(yearly_averages)
# Out:
# --- Russian Production In Thousand Barrels Per Day And Thousands Of Tonnes (2022 - 2025) ---
#        Production_TBPD  Production_K_Tonnes
# Month
# 2022      10320.337406          1407.958718
# 2023      10279.203041          1402.346936
# 2024       9892.603809          1349.604885
# 2025       9848.459447          1343.582462

# %%
"2. How much has imports to europe decreased?"

# %%
#By the prior questions we can find how much has been redirected vs shut in
